# %% [markdown]
# # German Mammals GBIF
#
# Using the Data from GBIF to create the list of German Mammals

# %%
from pygbif import species as species
from pygbif import occurrences as occ 
import zipfile
# we refer to the occurrence module as occ

import os
import pandas as pd

# %% [markdown]
# Finding the keys for the different taxon levels can be a little tricky if you do not know where or how to look.
#
# For example here we want to find mammals in Germany. We can check the documentation of occ.search() on by following this link: https://pygbif.readthedocs.io/en/latest/docs/usecases.html
#
# There we find that our class key is an integer "classKey – [int] Class classification key". But we do not have a list of classes and there corrisponding integers. Which is confusing (if this exists please send me the link). If you are like me you will try entering a string like 'mammalia' anyway only to get a trackback. So what you can do instead is to the URL for the taxon level of interest and pull the key from there for mammals that is this https://www.gbif.org/species/359. the classKey = 359.
#
# occ.search() allows us to specify several parameters. Including country, here the documentation is fairly straight forward and is as follows: 'country – [str] The 2-letter country code (as per ISO-3166-1) of the country in which the occurrence was recorded. See here http://en.wikipedia.org/wiki/ISO_3166-1_alpha-2´
#
# We can visit the link and find that the two letter string for Germany is 'DE', or that Samoa is 'WS'.
#
# There are several other arguments that are imporant
# 1. limit-which gives the number of returned records the default is 300 and the limit is 1000.
# 2. offset-which indicates where to start from
# 3. q - allows search with a word or phrase
#
# Alright now lets try it by looking at the first 10 mammal records.

# %%
occ.search(classKey=359,country='DE', limit=10)
# Out:
# {'offset': 0,
#  'limit': 10,
#  'endOfRecords': False,
#  'count': 835559,
#  'results': [{'key': 5004507484,
#    'datasetKey': 'aa6c5ee6-d4d7-4a65-a04f-379cffbf4842',
#    'publishingOrgKey': '2754e9c0-0e43-4f65-968a-6f16b9c378ce',
#    'installationKey': 'dcceb601-2fb0-49dc-9cd2-7c00056f2b2c',
#    'hostingOrganizationKey': '2754e9c0-0e43-4f65-968a-6f16b9c378ce',
#    'publishingCountry': 'DE',
#    'protocol': 'BIOCASE',
#    'lastCrawled': '2025-11-17T11:37:19.101+00:00',
#    'lastParsed': '2025-11-17T11:52:41.317+00:00',
#    'crawlId': 368,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': 'RQPW',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': 'RQPW',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4CW', 'name': 'Castorimorpha', 'rank': 'SUBORDER'},
#       {'key': '7SK', 'name': 'Castoridae', 'rank': 'FAMILY'},
#       {'key': '62KLV', 'name': 'Castor', 'rank': 'GENUS'},
#       {'key': 'RQPW', 'name': 'Castor fiber', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '4409131',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '4409131',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '5493', 'name': 'Castoridae', 'rank': 'FAMILY'},
#       {'key': '3240758', 'name': 'Castor', 'rank': 'GENUS'},
#       {'key': '4409131', 'name': 'Castor fiber', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 4409131,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 5493,
#    'genusKey': 3240758,
#    'speciesKey': 4409131,
#    'acceptedTaxonKey': 4409131,
#    'scientificName': 'Castor fiber Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Castor fiber Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Castoridae',
#    'genus': 'Castor',
#    'species': 'Castor fiber',
#    'genericName': 'Castor',
#    'specificEpithet': 'fiber',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'dateIdentified': '2025-01-03T21:54:06',
#    'decimalLatitude': 52.468672,
#    'decimalLongitude': 13.454184,
#    'coordinateUncertaintyInMeters': 3536.0,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.3_1', 'name': 'Berlin'},
#     'level2': {'gid': 'DEU.3.1_1', 'name': 'Berlin'},
#     'level3': {'gid': 'DEU.3.1.1_1', 'name': 'Berlin'}},
#    'year': 2025,
#    'month': 1,
#    'day': 2,
#    'eventDate': '2025-01-02',
#    'startDayOfYear': 2,
#    'endDayOfYear': 2,
#    'issues': ['COUNTRY_DERIVED_FROM_COORDINATES',
#     'CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2025-01-03T21:54:06.000+00:00',
#    'lastInterpreted': '2025-11-17T11:52:41.317+00:00',
#    'references': 'https://artenfinder.net/api/v2/sichtbeobachtungen/55180488?format=xml',
#    'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '6c1e7a7e-2b0b-5ea3-943f-ed0bffefc37f'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'identifier': '6c1e7a7e-2b0b-5ea3-943f-ed0bffefc37f',
#    'catalogNumber': '6c1e7a7e-2b0b-5ea3-943f-ed0bffefc37f',
#    'institutionCode': 'https://artenfinder.net',
#    'collectionCode': 'artenfinder',
#    'gbifID': '5004507484',
#    'occurrenceID': '6c1e7a7e-2b0b-5ea3-943f-ed0bffefc37f'},
#   {'key': 5004953105,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:37:18.842+00:00',
#    'crawlId': 170,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 6,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': 'QSF3',
#       'name': 'Capreolus capreolus (Linnaeus, 1758)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Linnaeus, 1758)',
#       'genericName': 'Capreolus',
#       'specificEpithet': 'capreolus',
#       'formattedName': '<i>Capreolus</i> <i>capreolus</i> (Linnaeus, 1758)'},
#      'acceptedUsage': {'key': 'QSF3',
#       'name': 'Capreolus capreolus (Linnaeus, 1758)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Linnaeus, 1758)',
#       'genericName': 'Capreolus',
#       'specificEpithet': 'capreolus',
#       'formattedName': '<i>Capreolus</i> <i>capreolus</i> (Linnaeus, 1758)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '6227M', 'name': 'Artiodactyla', 'rank': 'ORDER'},
#       {'key': '7XR', 'name': 'Cervidae', 'rank': 'FAMILY'},
#       {'key': '626SC', 'name': 'Capreolinae', 'rank': 'SUBFAMILY'},
#       {'key': '3H5R', 'name': 'Capreolus', 'rank': 'GENUS'},
#       {'key': 'QSF3', 'name': 'Capreolus capreolus', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '5220126',
#       'name': 'Capreolus capreolus (Linnaeus, 1758)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Linnaeus, 1758)',
#       'genericName': 'Capreolus',
#       'specificEpithet': 'capreolus',
#       'formattedName': '<i>Capreolus</i> <i>capreolus</i> (Linnaeus, 1758)'},
#      'acceptedUsage': {'key': '5220126',
#       'name': 'Capreolus capreolus (Linnaeus, 1758)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Linnaeus, 1758)',
#       'genericName': 'Capreolus',
#       'specificEpithet': 'capreolus',
#       'formattedName': '<i>Capreolus</i> <i>capreolus</i> (Linnaeus, 1758)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '731', 'name': 'Artiodactyla', 'rank': 'ORDER'},
#       {'key': '5298', 'name': 'Cervidae', 'rank': 'FAMILY'},
#       {'key': '2440927', 'name': 'Capreolus', 'rank': 'GENUS'},
#       {'key': '5220126', 'name': 'Capreolus capreolus', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 5220126,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 731,
#    'familyKey': 5298,
#    'genusKey': 2440927,
#    'speciesKey': 5220126,
#    'acceptedTaxonKey': 5220126,
#    'scientificName': 'Capreolus capreolus (Linnaeus, 1758)',
#    'scientificNameAuthorship': '(Linnaeus, 1758)',
#    'acceptedScientificName': 'Capreolus capreolus (Linnaeus, 1758)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Artiodactyla',
#    'family': 'Cervidae',
#    'genus': 'Capreolus',
#    'species': 'Capreolus capreolus',
#    'genericName': 'Capreolus',
#    'specificEpithet': 'capreolus',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 52.584731,
#    'decimalLongitude': 11.920153,
#    'coordinateUncertaintyInMeters': 25.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Sachsen-Anhalt',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.13_1', 'name': 'Sachsen-Anhalt'},
#     'level2': {'gid': 'DEU.13.13_1', 'name': 'Stendal'},
#     'level3': {'gid': 'DEU.13.13.7_1', 'name': 'Stendal'}},
#    'year': 2025,
#    'month': 1,
#    'day': 3,
#    'eventDate': '2025-01-03',
#    'startDayOfYear': 3,
#    'endDayOfYear': 3,
#    'issues': [],
#    'modified': '2025-01-03T13:35:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:37:18.842+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336423670'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 20559',
#    'samplingProtocol': 'unknown',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336423670',
#    'vernacularName': 'European Roe Deer',
#    'habitat': 'unknown',
#    'locality': 'SDL Stendal (Landkreis)',
#    'eventTime': '14:35',
#    'identificationVerificationStatus': 'Approved | Automated',
#    'gbifID': '5004953105',
#    'occurrenceID': 'https://observation.org/observation/336423670',
#    'eventType': 'Observation'},
#   {'key': 5004961333,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:38:34.409+00:00',
#    'crawlId': 170,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/109940332.jpg',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Theo Terlutter',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/109940332',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/creator': 'Theo Terlutter'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '54M2V',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '54M2V',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': 'CFSF7', 'name': 'Eulipotyphla', 'rank': 'ORDER'},
#       {'key': 'GWL', 'name': 'Talpidae', 'rank': 'FAMILY'},
#       {'key': '62922', 'name': 'Talpinae', 'rank': 'SUBFAMILY'},
#       {'key': 'L9K', 'name': 'Talpini', 'rank': 'TRIBE'},
#       {'key': '7S8Q', 'name': 'Talpa', 'rank': 'GENUS'},
#       {'key': '54M2V', 'name': 'Talpa europaea', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '7872906',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '7872906',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '803', 'name': 'Soricomorpha', 'rank': 'ORDER'},
#       {'key': '9469', 'name': 'Talpidae', 'rank': 'FAMILY'},
#       {'key': '2436127', 'name': 'Talpa', 'rank': 'GENUS'},
#       {'key': '7872906', 'name': 'Talpa europaea', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 7872906,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 803,
#    'familyKey': 9469,
#    'genusKey': 2436127,
#    'speciesKey': 7872906,
#    'acceptedTaxonKey': 7872906,
#    'scientificName': 'Talpa europaea Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Talpa europaea Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Soricomorpha',
#    'family': 'Talpidae',
#    'genus': 'Talpa',
#    'species': 'Talpa europaea',
#    'genericName': 'Talpa',
#    'specificEpithet': 'europaea',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 51.979517,
#    'decimalLongitude': 7.614872,
#    'continent': 'EUROPE',
#    'stateProvince': 'Nordrhein-Westfalen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.10_1', 'name': 'Nordrhein-Westfalen'},
#     'level2': {'gid': 'DEU.10.33_1', 'name': 'Münster'},
#     'level3': {'gid': 'DEU.10.33.1_1', 'name': 'Münster'}},
#    'year': 2025,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2025-01-01',
#    'startDayOfYear': 1,
#    'endDayOfYear': 1,
#    'issues': [],
#    'modified': '2025-04-16T17:12:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:38:34.409+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336220414'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Theo Terlutter',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Theo Terlutter',
#      'identifier': 'https://observation.org/photos/109940332.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 164154',
#    'samplingProtocol': 'other tracks',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336220414',
#    'vernacularName': 'European Mole',
#    'habitat': 'unknown',
#    'locality': 'MS Münster-Uppenberg',
#    'eventTime': '06:16',
#    'identificationVerificationStatus': 'Approved | Expert',
#    'gbifID': '5004961333',
#    'occurrenceID': 'https://observation.org/observation/336220414',
#    'eventType': 'Observation'},
#   {'key': 5004966577,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:39:53.995+00:00',
#    'crawlId': 170,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/109955320.jpg',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Koch Hildegard',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/109955320',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/creator': 'Koch Hildegard'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': 'RQPW',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': 'RQPW',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4CW', 'name': 'Castorimorpha', 'rank': 'SUBORDER'},
#       {'key': '7SK', 'name': 'Castoridae', 'rank': 'FAMILY'},
#       {'key': '62KLV', 'name': 'Castor', 'rank': 'GENUS'},
#       {'key': 'RQPW', 'name': 'Castor fiber', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '4409131',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '4409131',
#       'name': 'Castor fiber Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Castor',
#       'specificEpithet': 'fiber',
#       'formattedName': '<i>Castor</i> <i>fiber</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '5493', 'name': 'Castoridae', 'rank': 'FAMILY'},
#       {'key': '3240758', 'name': 'Castor', 'rank': 'GENUS'},
#       {'key': '4409131', 'name': 'Castor fiber', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 4409131,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 5493,
#    'genusKey': 3240758,
#    'speciesKey': 4409131,
#    'acceptedTaxonKey': 4409131,
#    'scientificName': 'Castor fiber Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Castor fiber Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Castoridae',
#    'genus': 'Castor',
#    'species': 'Castor fiber',
#    'genericName': 'Castor',
#    'specificEpithet': 'fiber',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 48.670458,
#    'decimalLongitude': 10.808457,
#    'continent': 'EUROPE',
#    'stateProvince': 'Bayern',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.2_1', 'name': 'Bayern'},
#     'level2': {'gid': 'DEU.2.25_1', 'name': 'Donau-Ries'},
#     'level3': {'gid': 'DEU.2.25.9_1', 'name': 'Mertingen'}},
#    'year': 2025,
#    'month': 1,
#    'day': 1,
#    'eventDate': '2025-01-01',
#    'startDayOfYear': 1,
#    'endDayOfYear': 1,
#    'issues': [],
#    'modified': '2025-01-02T16:21:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:39:53.995+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336264476'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Koch Hildegard',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Koch Hildegard',
#      'identifier': 'https://observation.org/photos/109955320.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 940298',
#    'samplingProtocol': 'feeding signs',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336264476',
#    'vernacularName': 'Eurasian Beaver',
#    'habitat': 'unknown',
#    'locality': 'DON Donau-Ries (Landkreis)',
#    'eventTime': '13:15',
#    'identificationVerificationStatus': 'Approved | Expert | Evidence',
#    'gbifID': '5004966577',
#    'occurrenceID': 'https://observation.org/observation/336264476',
#    'eventType': 'Observation'},
#   {'key': 5004967160,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:41:23.182+00:00',
#    'crawlId': 170,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4FD', 'name': 'Sciuromorpha', 'rank': 'SUBORDER'},
#       {'key': 'G48', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': 'KB9', 'name': 'Sciurinae', 'rank': 'SUBFAMILY'},
#       {'key': 'L87', 'name': 'Sciurini', 'rank': 'TRIBE'},
#       {'key': '63TBP', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8NYZP', 'name': 'Sciurus', 'rank': 'SUBGENUS'},
#       {'key': '79Y2K', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '9456', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': '2437489', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8211070', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 8211070,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 9456,
#    'genusKey': 2437489,
#    'speciesKey': 8211070,
#    'acceptedTaxonKey': 8211070,
#    'scientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Sciuridae',
#    'genus': 'Sciurus',
#    'species': 'Sciurus vulgaris',
#    'genericName': 'Sciurus',
#    'specificEpithet': 'vulgaris',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 51.435687,
#    'decimalLongitude': 7.281225,
#    'coordinateUncertaintyInMeters': 10.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Nordrhein-Westfalen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.10_1', 'name': 'Nordrhein-Westfalen'},
#     'level2': {'gid': 'DEU.10.11_1', 'name': 'Ennepe-Ruhr-Kreis'},
#     'level3': {'gid': 'DEU.10.11.9_1', 'name': 'Witten'}},
#    'year': 2025,
#    'month': 1,
#    'day': 4,
#    'eventDate': '2025-01-04',
#    'startDayOfYear': 4,
#    'endDayOfYear': 4,
#    'issues': [],
#    'modified': '2025-01-04T12:46:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:41:23.182+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336497988'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 929262',
#    'samplingProtocol': 'unknown',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336497988',
#    'vernacularName': 'Eurasian Red Squirrel',
#    'habitat': 'unknown',
#    'locality': 'BO/EN Bochum/Witten - Kemnader See',
#    'identificationVerificationStatus': 'Approved | Automated',
#    'gbifID': '5004967160',
#    'occurrenceID': 'https://observation.org/observation/336497988',
#    'eventType': 'Observation'},
#   {'key': 5004974983,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:38:33.798+00:00',
#    'crawlId': 170,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/109966775.jpg',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Anne-Kathrin Bunte',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/109966775',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/creator': 'Anne-Kathrin Bunte'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4FD', 'name': 'Sciuromorpha', 'rank': 'SUBORDER'},
#       {'key': 'G48', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': 'KB9', 'name': 'Sciurinae', 'rank': 'SUBFAMILY'},
#       {'key': 'L87', 'name': 'Sciurini', 'rank': 'TRIBE'},
#       {'key': '63TBP', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8NYZP', 'name': 'Sciurus', 'rank': 'SUBGENUS'},
#       {'key': '79Y2K', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '9456', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': '2437489', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8211070', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 8211070,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 9456,
#    'genusKey': 2437489,
#    'speciesKey': 8211070,
#    'acceptedTaxonKey': 8211070,
#    'scientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Sciuridae',
#    'genus': 'Sciurus',
#    'species': 'Sciurus vulgaris',
#    'genericName': 'Sciurus',
#    'specificEpithet': 'vulgaris',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 52.114842,
#    'decimalLongitude': 8.684629,
#    'continent': 'EUROPE',
#    'stateProvince': 'Nordrhein-Westfalen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.10_1', 'name': 'Nordrhein-Westfalen'},
#     'level2': {'gid': 'DEU.10.19_1', 'name': 'Herford'},
#     'level3': {'gid': 'DEU.10.19.3_1', 'name': 'Herford'}},
#    'year': 2025,
#    'month': 1,
#    'day': 2,
#    'eventDate': '2025-01-02',
#    'startDayOfYear': 2,
#    'endDayOfYear': 2,
#    'issues': [],
#    'modified': '2025-01-08T16:03:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:38:33.798+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336297836'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Anne-Kathrin Bunte',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Anne-Kathrin Bunte',
#      'identifier': 'https://observation.org/photos/109966775.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 741216',
#    'samplingProtocol': 'seen',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336297836',
#    'vernacularName': 'Eurasian Red Squirrel',
#    'habitat': 'unknown',
#    'locality': 'HF Herford (Kreis)',
#    'eventTime': '09:57',
#    'identificationVerificationStatus': 'Approved | Expert | Evidence',
#    'gbifID': '5004974983',
#    'occurrenceID': 'https://observation.org/observation/336297836',
#    'eventType': 'Observation'},
#   {'key': 5004975090,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:41:14.452+00:00',
#    'crawlId': 170,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/109979651.jpg',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Lidwien Smit',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/109979651',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/creator': 'Lidwien Smit'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '79Y2K',
#       'name': 'Sciurus (Sciurus) vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'infragenericEpithet': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> (<i>Sciurus</i>) <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4FD', 'name': 'Sciuromorpha', 'rank': 'SUBORDER'},
#       {'key': 'G48', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': 'KB9', 'name': 'Sciurinae', 'rank': 'SUBFAMILY'},
#       {'key': 'L87', 'name': 'Sciurini', 'rank': 'TRIBE'},
#       {'key': '63TBP', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8NYZP', 'name': 'Sciurus', 'rank': 'SUBGENUS'},
#       {'key': '79Y2K', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '8211070',
#       'name': 'Sciurus vulgaris Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Sciurus',
#       'specificEpithet': 'vulgaris',
#       'formattedName': '<i>Sciurus</i> <i>vulgaris</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '9456', 'name': 'Sciuridae', 'rank': 'FAMILY'},
#       {'key': '2437489', 'name': 'Sciurus', 'rank': 'GENUS'},
#       {'key': '8211070', 'name': 'Sciurus vulgaris', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 8211070,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 9456,
#    'genusKey': 2437489,
#    'speciesKey': 8211070,
#    'acceptedTaxonKey': 8211070,
#    'scientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Sciurus vulgaris Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Sciuridae',
#    'genus': 'Sciurus',
#    'species': 'Sciurus vulgaris',
#    'genericName': 'Sciurus',
#    'specificEpithet': 'vulgaris',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 53.338261,
#    'decimalLongitude': 9.984316,
#    'continent': 'EUROPE',
#    'stateProvince': 'Niedersachsen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.9_1', 'name': 'Niedersachsen'},
#     'level2': {'gid': 'DEU.9.17_1', 'name': 'Harburg'},
#     'level3': {'gid': 'DEU.9.17.5_1', 'name': 'Jesteburg'}},
#    'year': 2025,
#    'month': 1,
#    'day': 2,
#    'eventDate': '2025-01-02',
#    'startDayOfYear': 2,
#    'endDayOfYear': 2,
#    'issues': [],
#    'modified': '2025-01-08T16:03:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:41:14.452+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336336764'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Lidwien Smit',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Lidwien Smit',
#      'identifier': 'https://observation.org/photos/109979651.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 370561',
#    'samplingProtocol': 'seen',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336336764',
#    'vernacularName': 'Eurasian Red Squirrel',
#    'habitat': 'unknown',
#    'locality': 'WL Harburg (Landkreis)',
#    'eventTime': '09:50',
#    'identificationVerificationStatus': 'Approved | Expert | Evidence',
#    'gbifID': '5004975090',
#    'occurrenceID': 'https://observation.org/observation/336336764',
#    'eventType': 'Observation'},
#   {'key': 5004975187,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:38:59.263+00:00',
#    'crawlId': 170,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 4,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '3JBV8',
#       'name': 'Halichoerus grypus (Fabricius, 1791)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Fabricius, 1791)',
#       'genericName': 'Halichoerus',
#       'specificEpithet': 'grypus',
#       'formattedName': '<i>Halichoerus</i> <i>grypus</i> (Fabricius, 1791)'},
#      'acceptedUsage': {'key': '3JBV8',
#       'name': 'Halichoerus grypus (Fabricius, 1791)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Fabricius, 1791)',
#       'genericName': 'Halichoerus',
#       'specificEpithet': 'grypus',
#       'formattedName': '<i>Halichoerus</i> <i>grypus</i> (Fabricius, 1791)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': 'VS', 'name': 'Carnivora', 'rank': 'ORDER'},
#       {'key': '4CT', 'name': 'Caniformia', 'rank': 'SUBORDER'},
#       {'key': '625XL', 'name': 'Phocidae', 'rank': 'FAMILY'},
# ...
#       'specificEpithet': 'grypus',
#       'formattedName': '<i>Halichoerus</i> <i>grypus</i> (Fabricius, 1791)'},
#      'acceptedUsage': {'key': '2434806',
#       'name': 'Halichoerus grypus (Fabricius, 1791)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Fabricius, 1791)',
#       'genericName': 'Halichoerus',
#       'specificEpithet': 'grypus',
#       'formattedName': '<i>Halichoerus</i> <i>grypus</i> (Fabricius, 1791)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '732', 'name': 'Carnivora', 'rank': 'ORDER'},
#       {'key': '5310', 'name': 'Phocidae', 'rank': 'FAMILY'},
#       {'key': '2434805', 'name': 'Halichoerus', 'rank': 'GENUS'},
#       {'key': '2434806', 'name': 'Halichoerus grypus', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 2434806,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 732,
#    'familyKey': 5310,
#    'genusKey': 2434805,
#    'speciesKey': 2434806,
#    'acceptedTaxonKey': 2434806,
#    'scientificName': 'Halichoerus grypus (Fabricius, 1791)',
#    'scientificNameAuthorship': '(Fabricius, 1791)',
#    'acceptedScientificName': 'Halichoerus grypus (Fabricius, 1791)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Carnivora',
#    'family': 'Phocidae',
#    'genus': 'Halichoerus',
#    'species': 'Halichoerus grypus',
#    'genericName': 'Halichoerus',
#    'specificEpithet': 'grypus',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 54.710592,
#    'decimalLongitude': 8.361249,
#    'coordinateUncertaintyInMeters': 15.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Schleswig-Holstein',
#    'gadm': {},
#    'year': 2025,
#    'month': 1,
#    'day': 2,
#    'eventDate': '2025-01-02',
#    'startDayOfYear': 2,
#    'endDayOfYear': 2,
#    'issues': [],
#    'modified': '2025-01-02T16:56:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:38:59.263+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336369892'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 183180',
#    'samplingProtocol': 'unknown',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336369892',
#    'vernacularName': 'Grey Seal',
#    'habitat': 'unknown',
#    'locality': 'NF Amrum',
#    'eventTime': '14:04',
#    'identificationVerificationStatus': 'Approved | Automated',
#    'gbifID': '5004975187',
#    'occurrenceID': 'https://observation.org/observation/336369892',
#    'eventType': 'Observation'},
#   {'key': 5004975960,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:39:47.361+00:00',
#    'crawlId': 170,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '6RRQT',
#       'name': 'Myocastor coypus (Molina, 1782)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Molina, 1782)',
#       'genericName': 'Myocastor',
#       'specificEpithet': 'coypus',
#       'formattedName': '<i>Myocastor</i> <i>coypus</i> (Molina, 1782)'},
#      'acceptedUsage': {'key': '6RRQT',
#       'name': 'Myocastor coypus (Molina, 1782)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Molina, 1782)',
#       'genericName': 'Myocastor',
#       'specificEpithet': 'coypus',
#       'formattedName': '<i>Myocastor</i> <i>coypus</i> (Molina, 1782)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': '3Z5', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '4DX', 'name': 'Hystricomorpha', 'rank': 'SUBORDER'},
#       {'key': '4L7', 'name': 'Hystricognathi', 'rank': 'INFRAORDER'},
#       {'key': '9JX', 'name': 'Echimyidae', 'rank': 'FAMILY'},
#       {'key': 'JH9', 'name': 'Echimyinae', 'rank': 'SUBFAMILY'},
#       {'key': 'C49JX', 'name': 'Myocastorini', 'rank': 'TRIBE'},
#       {'key': '63CSF', 'name': 'Myocastor', 'rank': 'GENUS'},
#       {'key': '6RRQT', 'name': 'Myocastor coypus', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '4264680',
#       'name': 'Myocastor coypus (Molina, 1782)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Molina, 1782)',
#       'genericName': 'Myocastor',
#       'specificEpithet': 'coypus',
#       'formattedName': '<i>Myocastor</i> <i>coypus</i> (Molina, 1782)'},
#      'acceptedUsage': {'key': '4264680',
#       'name': 'Myocastor coypus (Molina, 1782)',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': '(Molina, 1782)',
#       'genericName': 'Myocastor',
#       'specificEpithet': 'coypus',
#       'formattedName': '<i>Myocastor</i> <i>coypus</i> (Molina, 1782)'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '1459', 'name': 'Rodentia', 'rank': 'ORDER'},
#       {'key': '3240572', 'name': 'Myocastoridae', 'rank': 'FAMILY'},
#       {'key': '3240573', 'name': 'Myocastor', 'rank': 'GENUS'},
#       {'key': '4264680', 'name': 'Myocastor coypus', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 4264680,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 1459,
#    'familyKey': 3240572,
#    'genusKey': 3240573,
#    'speciesKey': 4264680,
#    'acceptedTaxonKey': 4264680,
#    'scientificName': 'Myocastor coypus (Molina, 1782)',
#    'scientificNameAuthorship': '(Molina, 1782)',
#    'acceptedScientificName': 'Myocastor coypus (Molina, 1782)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Rodentia',
#    'family': 'Myocastoridae',
#    'genus': 'Myocastor',
#    'species': 'Myocastor coypus',
#    'genericName': 'Myocastor',
#    'specificEpithet': 'coypus',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 51.394694,
#    'decimalLongitude': 7.503712,
#    'coordinateUncertaintyInMeters': 5.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Nordrhein-Westfalen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.10_1', 'name': 'Nordrhein-Westfalen'},
#     'level2': {'gid': 'DEU.10.16_1', 'name': 'Hagen'},
#     'level3': {'gid': 'DEU.10.16.1_1', 'name': 'Hagen'}},
#    'year': 2025,
#    'month': 1,
#    'day': 2,
#    'eventDate': '2025-01-02',
#    'startDayOfYear': 2,
#    'endDayOfYear': 2,
#    'issues': [],
#    'modified': '2025-01-02T14:13:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:39:47.361+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336334333'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 163437',
#    'samplingProtocol': 'seen',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336334333',
#    'vernacularName': 'Coypu',
#    'habitat': 'unknown',
#    'locality': 'HA Hagen-Fley',
#    'eventTime': '15:13',
#    'identificationVerificationStatus': 'Approved | Automated',
#    'gbifID': '5004975960',
#    'occurrenceID': 'https://observation.org/observation/336334333',
#    'eventType': 'Observation'},
#   {'key': 5004978775,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-10-29T12:51:21.478+00:00',
#    'lastParsed': '2025-11-04T14:41:46.724+00:00',
#    'crawlId': 170,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/110066058.jpg',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Markus Pischel',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/110066058',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/creator': 'Markus Pischel'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'classifications': {'7ddf754f-d193-4cc9-b351-99906754a03b': {'usage': {'key': '54M2V',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '54M2V',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': 'CS5HF',
#        'name': 'Eukaryota',
#        'rank': 'DOMAIN'},
#       {'key': 'N', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': 'CH2', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '8V4V3', 'name': 'Vertebrata', 'rank': 'SUBPHYLUM'},
#       {'key': '8V4V5', 'name': 'Gnathostomata', 'rank': 'INFRAPHYLUM'},
#       {'key': '8VVWB', 'name': 'Osteichthyes', 'rank': 'PARVPHYLUM'},
#       {'key': '9CK8W', 'name': 'Tetrapoda', 'rank': 'MEGACLASS'},
#       {'key': '6224G', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '6226C', 'name': 'Theria', 'rank': 'SUBCLASS'},
#       {'key': 'LG', 'name': 'Eutheria', 'rank': 'INFRACLASS'},
#       {'key': 'CFSF7', 'name': 'Eulipotyphla', 'rank': 'ORDER'},
#       {'key': 'GWL', 'name': 'Talpidae', 'rank': 'FAMILY'},
#       {'key': '62922', 'name': 'Talpinae', 'rank': 'SUBFAMILY'},
#       {'key': 'L9K', 'name': 'Talpini', 'rank': 'TRIBE'},
#       {'key': '7S8Q', 'name': 'Talpa', 'rank': 'GENUS'},
#       {'key': '54M2V', 'name': 'Talpa europaea', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []},
#     'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c': {'usage': {'key': '7872906',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'acceptedUsage': {'key': '7872906',
#       'name': 'Talpa europaea Linnaeus, 1758',
#       'rank': 'SPECIES',
#       'code': 'ZOOLOGICAL',
#       'authorship': 'Linnaeus, 1758',
#       'genericName': 'Talpa',
#       'specificEpithet': 'europaea',
#       'formattedName': '<i>Talpa</i> <i>europaea</i> Linnaeus, 1758'},
#      'taxonomicStatus': 'ACCEPTED',
#      'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#       {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#       {'key': '359', 'name': 'Mammalia', 'rank': 'CLASS'},
#       {'key': '803', 'name': 'Soricomorpha', 'rank': 'ORDER'},
#       {'key': '9469', 'name': 'Talpidae', 'rank': 'FAMILY'},
#       {'key': '2436127', 'name': 'Talpa', 'rank': 'GENUS'},
#       {'key': '7872906', 'name': 'Talpa europaea', 'rank': 'SPECIES'}],
#      'iucnRedListCategoryCode': 'LC',
#      'issues': []}},
#    'taxonKey': 7872906,
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 359,
#    'orderKey': 803,
#    'familyKey': 9469,
#    'genusKey': 2436127,
#    'speciesKey': 7872906,
#    'acceptedTaxonKey': 7872906,
#    'scientificName': 'Talpa europaea Linnaeus, 1758',
#    'scientificNameAuthorship': 'Linnaeus, 1758',
#    'acceptedScientificName': 'Talpa europaea Linnaeus, 1758',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Soricomorpha',
#    'family': 'Talpidae',
#    'genus': 'Talpa',
#    'species': 'Talpa europaea',
#    'genericName': 'Talpa',
#    'specificEpithet': 'europaea',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'LC',
#    'decimalLatitude': 52.13546,
#    'decimalLongitude': 8.750401,
#    'continent': 'EUROPE',
#    'stateProvince': 'Nordrhein-Westfalen',
#    'gadm': {'level0': {'gid': 'DEU', 'name': 'Germany'},
#     'level1': {'gid': 'DEU.10_1', 'name': 'Nordrhein-Westfalen'},
#     'level2': {'gid': 'DEU.10.19_1', 'name': 'Herford'},
#     'level3': {'gid': 'DEU.10.19.9_1', 'name': 'Vlotho'}},
#    'year': 2025,
#    'month': 1,
#    'day': 5,
#    'eventDate': '2025-01-05',
#    'startDayOfYear': 5,
#    'endDayOfYear': 5,
#    'issues': [],
#    'modified': '2025-01-07T15:40:00.000+00:00',
#    'lastInterpreted': '2025-11-04T14:41:46.724+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '336577896'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Markus Pischel',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Markus Pischel',
#      'identifier': 'https://observation.org/photos/110066058.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 278749',
#    'samplingProtocol': 'other tracks',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Mammalia',
#    'countryCode': 'DE',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Germany',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '336577896',
#    'vernacularName': 'European Mole',
#    'habitat': 'unknown',
#    'locality': 'HF Herford (Kreis)',
#    'eventTime': '12:31',
#    'identificationVerificationStatus': 'Approved | Expert',
#    'gbifID': '5004978775',
#    'occurrenceID': 'https://observation.org/observation/336577896',
#    'eventType': 'Observation'}],
#  'facets': []}

# %% [markdown]
# The above output is not particularly readable, nor is it in the table format I would like for a list of species, we also have no idea how many records exist.
#
# To find the number of records lets use occ.count() however, here there is not argument classKey instead we use taxonKey

# %%
occ.count(taxonKey=359,country='DE')
# Out:
# 835559

# %% [markdown]
# 76,703 records is a lot.

# %%
occ.count(taxonKey=359,country='DE', isGeoreferenced=True)
# Out:
# 757967

# %% [markdown]
# We can see there are fewer records if we specify that we need the recored to be georeferanced.

# %% [markdown]
# Lets see if we can download the data and then simplify the output.
#
# An interesting quirk of the occ.download() method is that filters need to be passed as parameters. Using either

# %%
# Set GBIF credentials
os.environ["GBIF_USER"] = "your_gbif_username"
os.environ["GBIF_PWD"] = "your_gbif_password"
os.environ["GBIF_EMAIL"] = "your_gbif_email"

# Create download
download_key = occ.download(
    [
        'taxonKey = 359',
        'country = DE',
        'hasCoordinate = true'
    ],
    format="DWCA",  # or "SIMPLE_CSV", "SPECIES_LIST"
    user=os.environ["GBIF_USER"],
    pwd=os.environ["GBIF_PWD"],
    email=os.environ["GBIF_EMAIL"]
)

# %%
# Information about the download
print(download_key)
download_key = download_key[0]
print(download_key)
occ.download_meta(download_key)

# %%
# This just tracks the downloads progress
while True:
    meta = occ.download_meta(download_key)
    status = meta["status"]
    print(f"Current GBIF status: {status}")

    if status in ["SUCCEEDED", "FAILED", "CANCELLED", "KILLED"]:
        break

    time.sleep(60)  # check every 1 minute

if status == "SUCCEEDED":
    print("\n✅ GBIF download is finished!\n")
    print("\a")  # terminal bell / sound
else:
    print(f"\n⚠️ GBIF download ended with status: {status}\n")
    print("\a")  # still ping you

# %% [markdown]
# 835,559 records is a lot.

# %% [markdown]
# Because our request succeeded: 'status': 'SUCCEEDED' we can use the occ.download_get() to download the zipfile

# %%
# set the path to the path where you want to store the data
download = occ.download_get(
    download_key,
    path="outputs"
)

# %% [markdown]
# The download worked so now we have a zipfile

# %%
# path with the zip file
print(download)       # see the actual path, e.g. "outputs/00307....zip"
print(type(download)) # usually <class 'str'>
zip_path = download["path"]
print(zip_path)

# %%
# Extract data
outpath = "outputs/gbif_data"
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(outpath)

print(f"Extracted to directory {outpath}")

# %%
# Read the occurrence data
df = pd.read_csv("gbif_data/occurrence.txt", delimiter="\t")
df.head()

# %% [markdown]
# check the documentation on this page to find the column names and the meaning
# https://dwc.tdwg.org/terms/

# %%
selectedColumns = [
    'order',
    'family',
    'genus',
    'specificEpithet',
    'scientificName',
    'vernacularName',
    'decimalLatitude',
    'decimalLongitude'
]
dfv1 = df[selectedColumns]
dfv1.head()

# %%
# keep only the rows with complete species names
dfv1 = dfv1[dfv1['genus'].notnull()]
dfv1 = dfv1[dfv1['specificEpithet'].notnull()]
dfv1["species"] = dfv1["genus"]+ (" "+dfv1["specificEpithet"].fillna(""))

dfv1.head()

# %% [markdown]
# The above is super nice but we only want the unique species

# %%
# Collapse vernacular names per species
species_list = (
    dfv1.groupby(['order', 'family','scientificName'], as_index=False)
      .agg({'vernacularName': lambda x: ', '.join(sorted(set(x.dropna())))})
)
species_list.head()

#rowCount =  len(species_list)
#print(f"Number of species: {rowCount}")
# Out:
#           order           family                     scientificName  \
# 0  Afrosoricida       Tenrecidae     Echinops telfairi Martin, 1838
# 1  Afrosoricida       Tenrecidae  Tenrec ecaudatus (Schreber, 1778)
# 2  Artiodactyla  Anoplotheriidae         Anoplotherium Cuvier, 1804
# 3  Artiodactyla  Anoplotheriidae   Dacrytherium ovinum (Owen, 1857)
# 4  Artiodactyla  Anoplotheriidae          Diplobune Rütimeyer, 1862
#
#   vernacularName
# 0
# 1
# 2
# 3
# 4

# %%
species_only = species_list['species'].drop_duplicates().sort_values()
species_only.head()

species_count = len(species_only)
print(f"There are {species_count} in the list of mammals from germany")

# %%
species_list.to_csv("MammalsOfGermany.csv", index=False)
